# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import TimeSeriesSplit
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier
from sklearn.metrics import accuracy_score, classification_report
import joblib
import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv("RELIANCE_NS_features.csv")

FEATURES = [col for col in df.columns if col not in ['Close', 'Target']]
X = df[FEATURES]
y = df['Target']

print(f"Data: {X.shape}")
# Out:
# Data: (1225, 15)

# %%
#hyper-parameter tuning
from sklearn.model_selection import RandomizedSearchCV
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import Pipeline

param_grids = {
    "Logistic Regression": {
        'clf__C':       [0.001, 0.01, 0.1, 1, 10, 100],   # note the 'clf__' prefix
        'clf__penalty': ['l1', 'l2'],
        'clf__solver':  ['liblinear']
    },
    "Random Forest": {
        'n_estimators':      [100, 200, 300, 500],
        'max_depth':         [3, 5, 7, 10, None],
        'min_samples_split': [2, 5, 10],
        'min_samples_leaf':  [1, 2, 4],
        'max_features':      ['sqrt', 'log2']
    },
    "XGBoost": {
        'n_estimators':     [100, 200, 300],
        'max_depth':        [3, 4, 5, 6],
        'learning_rate':    [0.01, 0.05, 0.1],
        'subsample':        [0.7, 0.8, 1.0],
        'colsample_bytree': [0.7, 0.8, 1.0]
    }
}

base_models = {
    "Logistic Regression": Pipeline([
        ('scaler', StandardScaler()),
        ('clf', LogisticRegression(max_iter=1000))
    ]),
    "Random Forest":       RandomForestClassifier(random_state=42),
    "XGBoost":             XGBClassifier(random_state=42, eval_metric='logloss')
}

# %%
#Tune Each Model with RandomizedSearchCV

tscv = TimeSeriesSplit(n_splits=5)
tuned_models = {}
cv_results = {}

for name, model in base_models.items():
    search = RandomizedSearchCV(
        model,
        param_distributions=param_grids[name],
        n_iter=20,
        cv=TimeSeriesSplit(n_splits=3),   # nested CV for tuning
        scoring='accuracy',
        random_state=42,
        n_jobs=-1
    )
    search.fit(X, y)   # fit on full data; inner CV handles the splitting
    tuned_models[name] = search.best_estimator_
    cv_results[name] = search.best_score_
    print(f"{name:20s}: {search.best_score_:.4f} | Best params: {search.best_params_}")

best_name  = max(cv_results, key=cv_results.get)
best_model = tuned_models[best_name]
print(f"\nBest model: {best_name}")
# Out:
# Logistic Regression : 0.5033 | Best params: {'clf__solver': 'liblinear', 'clf__penalty': 'l2', 'clf__C': 0.01}
# Random Forest       : 0.4891 | Best params: {'n_estimators': 100, 'min_samples_split': 2, 'min_samples_leaf': 2, 'max_features': 'sqrt', 'max_depth': None}
# XGBoost             : 0.4924 | Best params: {'subsample': 1.0, 'n_estimators': 300, 'max_depth': 6, 'learning_rate': 0.05, 'colsample_bytree': 0.8}
#
# Best model: Logistic Regression

# %%
#Final Train on Last Fold (for backtest + evaluation)
# Use the last split (most recent, largest train set) for final model + backtest
train_idx, test_idx = list(tscv.split(X))[-1]
X_train, X_test = X.iloc[train_idx], X.iloc[test_idx]
y_train, y_test = y.iloc[train_idx], y.iloc[test_idx]

best_model.fit(X_train, y_train)
preds = best_model.predict(X_test)

print(classification_report(y_test, preds, target_names=['Down', 'Up']))
# Out:
#               precision    recall  f1-score   support
#
#         Down       0.45      0.83      0.58        94
#           Up       0.45      0.12      0.19       110
#
#     accuracy                           0.45       204
#    macro avg       0.45      0.47      0.38       204
# weighted avg       0.45      0.45      0.37       204

# %%
best_model.coef_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[54], line 1
# ----> 1 best_model.coef_
#
# AttributeError: 'Pipeline' object has no attribute 'coef_'

# %%
#feature importances
import seaborn as sns
#since logistic regression if the best model it doesnt have feature_importances_ we need to use coefs_

# Access the classifier step inside the pipeline
coefs = best_model.named_steps['clf'].coef_[0]
importance = pd.Series(coefs, index=FEATURES).abs()
title = f"Feature Importance (|Coefficient|) — {best_name}"

importance.sort_values().plot(kind='barh', figsize=(8, 6), color='steelblue')
plt.title(title)
plt.tight_layout()
plt.show()

# %%
def backtest(df, test_idx, predictions, risk_free=0.06):
    test = df.iloc[test_idx].copy()
    test['Pred'] = predictions
    test['Return_1d'] = test['Close'].pct_change()

    test['Strategy_Return'] = test['Return_1d'] * test['Pred'].shift(1)
    test['Cum_Strategy'] = (1 + test['Strategy_Return']).cumprod()
    test['Cum_Market']   = (1 + test['Return_1d']).cumprod()

    def sharpe(r): return np.sqrt(252) * (r.mean() - risk_free/252) / r.std()
    def max_dd(cum): return ((cum - cum.cummax()) / cum.cummax()).min()

    metrics = {
        'Strategy Sharpe':   sharpe(test['Strategy_Return'].dropna()),
        'Market Sharpe':     sharpe(test['Return_1d'].dropna()),
        'Strategy Drawdown': max_dd(test['Cum_Strategy']),
        'Market Drawdown':   max_dd(test['Cum_Market']),
        'Strategy Return':   test['Cum_Strategy'].iloc[-1] - 1,
        'Market Return':     test['Cum_Market'].iloc[-1] - 1,
    }
    return test, metrics

test_df, metrics = backtest(df, test_idx, preds)

for k, v in metrics.items():
    print(f"{k:20s}: {v:.2%}" if 'Return' in k or 'Drawdown' in k else f"{k:20s}: {v:.2f}")
# Out:
# Strategy Sharpe     : -0.81
# Market Sharpe       : 1.06
# Strategy Drawdown   : -5.23%
# Market Drawdown     : -14.82%
# Strategy Return     : -1.33%
# Market Return       : 19.91%

# %%
#Plot Strategy vs Market

test_df[['Cum_Strategy', 'Cum_Market']].plot(
    figsize=(12, 5), title=f'{best_name} Strategy vs Buy & Hold'
)
plt.ylabel('Portfolio Value (Start = 1)')
plt.legend(['ML Strategy', 'Buy & Hold'])
plt.tight_layout()
plt.show()

# %%
# import joblib

fname = best_name.replace(' ', '_').lower()
joblib.dump(best_model, f"{fname}_model.pkl")
print(f"Saved: {fname}_model.pkl")

# Also save the feature list — you'll need this exact order in Streamlit
joblib.dump(FEATURES, "feature_list.pkl")
print("Saved: feature_list.pkl")
# Out:
# Saved: logistic_regression_model.pkl
# Saved: feature_list.pkl
